# %%
"""
Cat years, dog years
I have a cat and a dog.

I got them at the same time as kitten/puppy. That was humanYears years ago.

Return their respective ages now as [humanYears,catYears,dogYears]

NOTES:
humanYears >= 1
humanYears are whole numbers only

Cat Years
15 cat years for first year
+9 cat years for second year
+4 cat years for each year after that

Dog Years
15 dog years for first year
+9 dog years for second year
+5 dog years for each year after that 

Link: https://www.codewars.com/kata/5a6663e9fd56cb5ab800008b/java
"""
human_years = 4

cat_years = dog_years = 0
#Calculamos la edad del gato y perro 
if human_years == 1:
    cat_years = dog_years = 15
elif human_years == 2:
    cat_years = dog_years = 24
else:
    cat_years = dog_years = 24
    if human_years >= 3:
        for i in range(human_years-2):
            cat_years+=4
            dog_years+=5
        
print(f"[{human_years},{cat_years},{dog_years}]")

'''
age = input(Introduzca su edad: )
'''
# Out:
# [4,32,34]

# %%
def aspect_resolution_16_9(width = 0, height = 0):
    redimension_width = round (height * 1.77, 0)
    return [redimension_width, height]


# 374 × 280
new_resolution = aspect_resolution_16_9(374, 280)
new_resolution
# Out:
# [496.0, 280]

# %%
num1 = int(input("Ingrese el primer numero: "))
num2 = int(input("Ingrese el primer numero: "))

print(f"{num1}+{num2}={num1+num2}")
print(f"{num1}-{num2}={num1-num2}")
print(f"{num1}*{num2}={num1*num2}")
print(f"{num1}/{num2}={num1/num2}")
# Out:
# Ingrese el primer numero:  7
# Ingrese el primer numero:  4
# 7+4=11
# 7-4=3
# 7/4=1.75
# 7*4=28

# %%
str_name = "James"

n_str = len(str_name)

new_word =""
if n_str % 2 ==0:
    new_word = str_name[0] + str_name[n_str/2] + str_name[n_str-1]
else:
    new_word = str_name[0] + str_name[(n_str+1)/2] + str_name[n_str-1]

new_word
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       7     new_word = str_name[0] + str_name[n_str/2] + str_name[n_str-1]
#       8 else:
# ----> 9     new_word = str_name[0] + str_name[(n_str+1)/2] + str_name[n_str-1]
#      11 new_word
#
# TypeError: string indices must be integers, not 'float'
