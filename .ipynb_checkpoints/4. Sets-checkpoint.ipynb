# %%
conjunto_vacio = set() # se define de esta manera para no confundir con los diccionarios

# %%
numeros = {1,2,3,4,5} # no se puede acceder a los elementos individuales de manera directa

# %%
frutas = {'manzana','banana','cereza'} # no se puede acceder por su posicion, no aon ordenados, se tiene que recorrer todo el conjunto

# %%
#Para acceder a los elementos debemos de usar un for
for fruta in frutas:
    print(fruta)
# Out:
# cereza
# banana
# manzana

# %%
'manzana' in frutas
# Out:
# True

# %%
frutas = {'manzana','banana','cereza','manzana'}

# %%
print(frutas)
# Out:
# {'cereza', 'banana', 'manzana'}

# %%
numeros.add('mango')

# %%
print(numeros)
# Out:
# {1, 2, 3, 4, 5, 'mango'}

# %%
numeros.remove('mango')

# %%
print(numeros)
# Out:
# {1, 2, 3, 4, 5}

# %%
numeros.discard(5)

# %%
print(numeros)
# Out:
# {1, 2, 3, 4}

# %%
numeros.update([7,8,9])

# %%
print(numeros)
# Out:
# {1, 2, 3, 4, 7, 8, 9}

# %%
20 in numeros
# Out:
# False

# %%
a = {1,2,3,4}
b = {3,4,5,6}

# %%
a | b
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
a & b
# Out:
# {3, 4}

# %%
a - b
# Out:
# {1, 2}

# %%
b - a
# Out:
# {5, 6}

# %%
a ^ b
# Out:
# {1, 2, 5, 6}

# %%
ids = [1,2,5,2,4,1,3]

# %%
ids = set(ids)

# %%
ids
# Out:
# {1, 2, 3, 4, 5}

# %%
ids = list(ids)

# %%
ids
# Out:
# [1, 2, 3, 4, 5]
