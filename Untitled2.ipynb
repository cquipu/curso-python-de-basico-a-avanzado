# %%
L1 = ['manzana',2,'pera']

# %%
print(L1[0])
# Out:
# manzana

# %%
frutas = ['manzana','pera','cereza']

# %%
frutas.append('naranja')

# %%
print(frutas)
# Out:
# ['manzana', 'pera', 'cereza', 'naranja', 'naranja']

# %%
frutas.insert(1,'kiwi')

# %%
print(frutas)
# Out:
# ['manzana', 'kiwi', 'pera', 'cereza', 'naranja', 'naranja']

# %%
frutas.remove('naranja')

# %%
print(frutas)
# Out:
# ['manzana', 'kiwi', 'pera', 'cereza', 'naranja']

# %%
del frutas[4]

# %%
print(frutas)
# Out:
# ['manzana', 'kiwi', 'pera', 'cereza']

# %%
ultimo = frutas.pop()
print(frutas)
print (ultimo)
# Out:
# ['manzana', 'kiwi']
# pera

# %%
len(frutas)
# Out:
# 2

# %%
palabra = "Hola"

# %%
nueva = list(palabra)

# %%
print(nueva)
# Out:
# ['H', 'o', 'l', 'a']

# %% [markdown]
# ## Tuplas

# %%
colores = ('rojo','verde','azul')

# %%
print(colores)
# Out:
# ('rojo', 'verde', 'azul')

# %%
tupla_vacia = ()
lista_vacia = []

# %%
solo_uno = (5,)

# %%
print(solo_uno)
# Out:
# (5,)

# %%
print(colores[-1])
# Out:
# azul

# %%
colores[0] = 'negro'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 colores[0] = 'negro'
#
# TypeError: 'tuple' object does not support item assignment

# %%
lista_colores = ['rojo','verde','azul']

# %%
print(lista_colores)
# Out:
# ['rojo', 'verde', 'azul']

# %%
lista_colores[0]='negro'

# %%
print(lista_colores)
# Out:
# ['negro', 'verde', 'azul']

# %%
t1 = (1,2,3)
t2 = (4,5,6)

# %%
t3=t1+t2

# %%
t3
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
3*t1
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)

# %%
l1=[1,2,3]

# %%
t1+l1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 t1+l1
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
print(7 in t1)
# Out:
# False

# %%
print(1 in t1)
# Out:
# True

# %%
l1[1:2]
# Out:
# [2]

# %%
t1[1:2]
# Out:
# (2,)

# %%
t1[1:3]
# Out:
# (2, 3)

# %% [markdown]
# ## Diccionarios

# %%
diccionario_vacio = {}
persona = {'nombre': 'Edson', 'edad': 30, 'ciudad':'Madrid'}

# %%
persona['nombre']
# Out:
# 'Edson'

# %%
persona.get('nombre')
# Out:
# 'Edson'

# %%
persona['apellido']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 persona['apellido']
#
# KeyError: 'apellido'

# %%
persona.get('apellido','valor no encontrado')
# Out:
# 'valor no encontrado'

# %%
print(persona)
# Out:
# {'nombre': 'Edson', 'edad': 30, 'ciudad': 'Madrid'}

# %%
persona['edad'] = 35

# %%
print(persona)
# Out:
# {'nombre': 'Edson', 'edad': 35, 'ciudad': 'Madrid'}

# %%
persona['profesion'] = 'ingeniero'

# %%
del persona['ciudad']

# %%
print(persona)
# Out:
# {'nombre': 'Edson', 'edad': 35, 'profesion': 'ingeniero'}

# %%
profesion = persona.pop('profesion')

# %%
print(profesion)
# Out:
# ingeniero

# %%
claves = persona.keys()

# %%
print(claves)
# Out:
# dict_keys(['nombre', 'edad'])

# %%
values = persona.values()

# %%
print(values)
# Out:
# dict_values(['Edson', 35])

# %%
elementos = persona.items()

# %%
print(elementos)
# Out:
# dict_items([('nombre', 'Edson'), ('edad', 35)])

# %%
len(persona)
# Out:
# 2

# %%
# iterando sobre claves
for key in persona.keys():
    print(key)
# Out:
# nombre
# edad

# %%
# iterando sobre valores
for value in persona.values():
    print(value)
# Out:
# Edson
# 35

# %%
# iterando sobre clave-valor
for key, value in persona.items():
    print(key, value)
# Out:
# nombre Edson
# edad 35

# %%
numeros = [1,2,3,4,5]
cuadrados = list(map(lambda x: x**2,  numeros))
print(cuadrados)
# Out:
# [1, 4, 9, 16, 25]

# %%
numeros = [1,2,3,4,5,6]
pares = list(filter(lambda x: x%2 == 0, numeros))
print(pares)
# Out:
# [2, 4, 6]

# %%
frutas = ['fresa','manzana','banana','cereza']
frutas_ordenadas = sorted(frutas, key = lambda fruta: len(fruta))
print(frutas_ordenadas)
# Out:
# ['fresa', 'banana', 'cereza', 'manzana']

# %%
suma = lambda a, b: a + b
print(suma(2,3))
# Out:
# 5
